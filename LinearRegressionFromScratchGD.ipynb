# %% [markdown]
# <a href="https://colab.research.google.com/github/antreev-brar/ML-projects/blob/master/LinearRegressionFromScratchGD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num_point=100
x = np.linspace(0, 100 , num_point)
y = np.linspace(0, 200 , num_point)

x+= np.random.normal(0,4,num_point)
y+= np.random.normal(0,4,num_point)
plt.scatter( x , y )
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(False)
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
np.ones(100)

# %%
m = 0 
c = 0

epochs = 1000
learning_rate=0.0001



print (loss)
for i in range(epochs):
  y_pred = m*x+c
  loss = np.sum((y - y_pred)**2 )/num_point
  print(i, " : " , loss )
  dm = -2/num_point * sum(((y-y_pred)*x))
  dc = -2/num_point * sum(((y-y_pred)))

  m = m - learning_rate * dm
  c = c - learning_rate * dc
print(m," ",c)
# Out:
# 27.390846231243735
# 0  :  13382.942383700183
# 1  :  1638.954966495528
# 2  :  253.8545232921438
# 3  :  90.49398721772735
# 4  :  71.22696278158809
# 5  :  68.95450485187231
# 6  :  68.68640706661735
# 7  :  68.65470599747825
# 8  :  68.65088585698011
# 9  :  68.65035403594874
# 10  :  68.65021005172291
# 11  :  68.650111817799
# 12  :  68.65001898807208
# 13  :  68.6499268040718
# 14  :  68.64983470457746
# 15  :  68.64974262339716
# 16  :  68.6496505527233
# 17  :  68.64955849163417
# 18  :  68.64946644002019
# 19  :  68.64937439786758
# 20  :  68.6492823651739
# 21  :  68.64919034193795
# 22  :  68.64909832815876
# 23  :  68.64900632383537
# 24  :  68.64891432896677
# 25  :  68.64882234355204
# 26  :  68.64873036759016
# 27  :  68.64863840108015
# 28  :  68.64854644402108
# 29  :  68.64845449641199
# 30  :  68.64836255825183
# 31  :  68.64827062953975
# 32  :  68.64817871027465
# 33  :  68.64808680045567
# 34  :  68.64799490008176
# 35  :  68.64790300915199
# ...

# %%
# Out:
# 0.0

# %%
xx = np.linspace(0,100,2)
yy = np.array(m*xx+c)

# %%
plt.figure(4)
plt.scatter( x , y ,s=40)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(xx,yy ,color = 'red')
plt.show()
